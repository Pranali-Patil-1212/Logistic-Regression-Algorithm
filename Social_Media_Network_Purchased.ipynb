# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranali-Patil-1212/Logistic-Regression-Algorithm/blob/main/Social_Media_Network_Purchased.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/All CSV_Files/Social_Network_Ads.csv")

# %%
data.head()
# Out:
#    Age  Purchased
# 0   19          0
# 1   35          0
# 2   26          0
# 3   27          0
# 4   19          0

# %%
sns.scatterplot(data=data, x="Age", y="Purchased")
plt.show()

# %%
x=data[["Age"]]
y=data["Purchased"]

# %%
print(x.shape)
y.shape
# Out:
# (400, 1)
# (400,)

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Purchased, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, train_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test, y_test)*100
# Out:
# 84.0625

# %%
data.tail()
# Out:
#      Age  Purchased
# 395   46          1
# 396   51          1
# 397   50          1
# 398   36          0
# 399   49          1

# %%
lr.predict([[19]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
lr.predict([[49]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
sns.scatterplot(x="Age", y="Purchased", data=data)
sns.lineplot(x="Age", y=lr.predict(x), data=data, color="red")
plt.show()
