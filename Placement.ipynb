# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranali-Patil-1212/Logistic-Regression-Algorithm/blob/main/Placement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/All CSV_Files/placement-dataset.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
data.drop(columns=[data.columns[0]], inplace=True)

# %%
data.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
sns.scatterplot(x="cgpa", y="iq", data=data)
plt.show()

# %%
sns.scatterplot(x="cgpa", y="placement", data=data)
plt.show()

# %%
x=data.iloc[:, :-1]
y=data["placement"]

# %%
x.head()
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: placement, dtype: int64

# %%
from sklearn.model_selection import train_test_split
